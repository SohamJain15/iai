# %%
import pandas as pd

# %%
Data = {
    'Age':[20,22,42,54,15,24,36],
    'Annual income':[10000,140000,50000,67000,87000,54000,100000],
    'Spending Score':[10,50,20,60,70,40,36]
}

df = pd.DataFrame(Data)
